# %% [markdown]
# # Assignment 10
# ## Applied Machine Learning
#
# Andrew Chan
# EBE869

# %% [markdown]
# # 1. [10 pts] Download the labeled dataset,
# if you like use a dummy email address for
# registration. There must be 8 data files, each representing a particular cyber-attack type
# and it's day, and it's collected pcap data

# %% [markdown]
# This assignment assumes that the following 8 .csv files are in the same directory as this notebook:
# * Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
# * Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
# * Friday-WorkingHours-Morning.pcap_ISCX.csv
# * Monday-WorkingHours.pcap_ISCX.csv
# * Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
# * Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
# * Tuesday-WorkingHours.pcap_ISCX.csv
# * Wednesday-workingHours.pcap_ISCX.csv

# %%
import os
print('Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')/1024**2) + ' MB')
print('Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')/1024**2) + ' MB')
print('Friday-WorkingHours-Morning.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Friday-WorkingHours-Morning.pcap_ISCX.csv')/1024**2) + ' MB')
print('Monday-WorkingHours.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Monday-WorkingHours.pcap_ISCX.csv')/1024**2) + ' MB')
print('Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv')/1024**2) + ' MB')
print('Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv')/1024**2) + ' MB')
print('Tuesday-WorkingHours.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Tuesday-WorkingHours.pcap_ISCX.csv')/1024**2) + ' MB')
print('Wednesday-workingHours.pcap_ISCX.csv \n  File size: ' + str(os.path.getsize('Wednesday-workingHours.pcap_ISCX.csv')/1024**2) + ' MB')
# Out:
# Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv
#   File size: 73.55104351043701 MB
# Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv
#   File size: 73.34343719482422 MB
# Friday-WorkingHours-Morning.pcap_ISCX.csv
#   File size: 55.61516284942627 MB
# Monday-WorkingHours.pcap_ISCX.csv
#   File size: 168.73161125183105 MB
# Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv
#   File size: 79.25265884399414 MB
# Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv
#   File size: 49.61324977874756 MB
# Tuesday-WorkingHours.pcap_ISCX.csv
#   File size: 128.82136821746826 MB
# Wednesday-workingHours.pcap_ISCX.csv
#   File size: 214.73540782928467 MB

# %% [markdown]
# # 2. [10 pts] Pick one of the data files, call it Dataset 1, and examine its features. Make sure it has more than one class value for its label

# %% [markdown]
# * Picked `Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv`

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import math
import numpy as np

# Locate and load the data file
df = pd.read_csv('Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv')

# Sanity check
print(f'N rows={len(df)}, M columns={len(df.columns)}')
df.head()
# Out:
# N rows=225745, M columns=79
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# 3                             6                       6
# 4                             0                       6
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       6                      6.0                     0.0
# 1                       6                      6.0                     0.0
# 2                       6                      6.0                     0.0
# 3                       6                      6.0                     0.0
# 4                       6                      6.0                     0.0
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     20          0.0          0.0            0
# 1  ...                     20          0.0          0.0            0
# 2  ...                     20          0.0          0.0            0
# 3  ...                     20          0.0          0.0            0
# 4  ...                     20          0.0          0.0            0
#
#     Active Min  Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0            0        0.0        0.0          0          0  BENIGN
# 1            0        0.0        0.0          0          0  BENIGN
# 2            0        0.0        0.0          0          0  BENIGN
# 3            0        0.0        0.0          0          0  BENIGN
# 4            0        0.0        0.0          0          0  BENIGN
#
# [5 rows x 79 columns]

# %%
df.columns.values
# Out:
# array([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
#        ' Bwd Packets/s', ' Min Packet Length', ' Max Packet Length',
#        ' Packet Length Mean', ' Packet Length Std',
#        ' Packet Length Variance', 'FIN Flag Count', ' SYN Flag Count',
#        ' RST Flag Count', ' PSH Flag Count', ' ACK Flag Count',
#        ' URG Flag Count', ' CWE Flag Count', ' ECE Flag Count',
#        ' Down/Up Ratio', ' Average Packet Size', ' Avg Fwd Segment Size',
#        ' Avg Bwd Segment Size', ' Fwd Header Length.1',
#        'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate',
#        'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean',
#        ' Idle Std', ' Idle Max', ' Idle Min', ' Label'], dtype=object)

# %%
df.dtypes
# Out:
#  Destination Port                int64
#  Flow Duration                   int64
#  Total Fwd Packets               int64
#  Total Backward Packets          int64
# Total Length of Fwd Packets      int64
#                                 ...
# Idle Mean                      float64
#  Idle Std                      float64
#  Idle Max                        int64
#  Idle Min                        int64
#  Label                          object
# Length: 79, dtype: object

# %%
df[' Label'].value_counts()
# Out:
# DDoS      128027
# BENIGN     97718
# Name:  Label, dtype: int64

# %% [markdown]
# # 3. [10 pts] For the Dataset 1, pick a machine learning methodology and justify your choice.

# %% [markdown]
# * I will choose Random Forest Classifier

# %% [markdown]
# # 4. [10 pts] Process the class feature/category as binary classes for supervised learning, assign BENIGN to value 0 and the rest to value 1. Check its balance for the Dataset 1

# %%
class_mapping = { 'BENIGN' : 0, 'DDoS' : 1 }

# %%
df[' Label'] = df[' Label'].map(class_mapping)

# %%
df[' Label'].value_counts()
# Out:
# 1    128027
# 0     97718
# Name:  Label, dtype: int64

# %% [markdown]
# # 5. [10 pts] Explore Dataset 1 features with respect to the class.
# (Hint: features Source Port
# and Destination Port are very useful, research and find out important networking port
# numbers and one-hot-encode them. Unimportant port numbers or source port numbers can
# be assigned to a feature called 'other ports')

# %%
df = df.fillna(df.mean())

# %% [markdown]
# ## One hot encoding

# %% [markdown]
# Convert `Destination Port` to string

# %% [markdown]
# Only include important ports

# %%
importantPorts = df[' Destination Port'].isin([20,21,22,23,25,53,80,110,119,123,143,161,194,443])

df[' Destination Port'] = df[' Destination Port'].where(importantPorts,'other ports')

df[' Destination Port'] = df[' Destination Port'].astype(str)

# %%
x = df[' Destination Port'].value_counts()

# %%
from sklearn.preprocessing import OneHotEncoder
X_y = df.values
X_y.shape

# %%
passthrough = []
for i in range(1,79):
    passthrough.append(i)

# %%
from sklearn.compose import ColumnTransformer
c_transf = ColumnTransformer([ 
    ('onehot', OneHotEncoder(), [0]),
    ('nothing', 'passthrough', passthrough)
])
X_y_ohe = c_transf.fit_transform(X_y).astype(float)

# %%
X_y_ohe.shape
# Out:
# (225745, 85)

# %% [markdown]
# # 6. [10 pts] Display some histograms and anything you deem fit to pick independent Dataset 1 features.
# (Hint: source/destination bytes, packets, ports and the duration features)

# %%
df_corr = df.corr()

# %%
sorted_df = df_corr.sort_values(by=' Label')

# %%
sorted_df
# Out:
#                          Flow Duration   Total Fwd Packets  \
#  URG Flag Count               0.130012           -0.063042
#  Min Packet Length           -0.222332           -0.080692
#  min_seg_size_forward        -0.112832           -0.005388
#  Bwd Packet Length Min       -0.150860           -0.058771
#  Avg Fwd Segment Size         0.257098            0.017458
# ...                                ...                 ...
#  Fwd Avg Packets/Bulk              NaN                 NaN
#  Fwd Avg Bulk Rate                 NaN                 NaN
#  Bwd Avg Bytes/Bulk                NaN                 NaN
#  Bwd Avg Packets/Bulk              NaN                 NaN
# Bwd Avg Bulk Rate                  NaN                 NaN
#
#                          Total Backward Packets  Total Length of Fwd Packets  \
#  URG Flag Count                        0.021412                     0.317221
#  Min Packet Length                    -0.070150                    -0.130595
#  min_seg_size_forward                  0.009922                    -0.048262
#  Bwd Packet Length Min                -0.040638                    -0.073738
#  Avg Fwd Segment Size                  0.032013                     0.858439
# ...                                         ...                          ...
#  Fwd Avg Packets/Bulk                       NaN                          NaN
#  Fwd Avg Bulk Rate                          NaN                          NaN
#  Bwd Avg Bytes/Bulk                         NaN                          NaN
#  Bwd Avg Packets/Bulk                       NaN                          NaN
# Bwd Avg Bulk Rate                           NaN                          NaN
#
#                          Total Length of Bwd Packets   Fwd Packet Length Max  \
#  URG Flag Count                            -0.061142                0.354549
#  Min Packet Length                         -0.075541               -0.135658
#  min_seg_size_forward                      -0.015588               -0.074322
#  Bwd Packet Length Min                     -0.047682               -0.076854
#  Avg Fwd Segment Size                      -0.042980                0.940954
# ...                                              ...                     ...
#  Fwd Avg Packets/Bulk                            NaN                     NaN
#  Fwd Avg Bulk Rate                               NaN                     NaN
#  Bwd Avg Bytes/Bulk                              NaN                     NaN
#  Bwd Avg Packets/Bulk                            NaN                     NaN
# Bwd Avg Bulk Rate                                NaN                     NaN
#
#                          Fwd Packet Length Min   Fwd Packet Length Mean  \
#  URG Flag Count                       0.282352                 0.426718
#  Min Packet Length                    0.046058                -0.123147
#  min_seg_size_forward                -0.000325                -0.077440
#  Bwd Packet Length Min                0.033618                -0.067832
#  Avg Fwd Segment Size                 0.277425                 1.000000
# ...                                        ...                      ...
#  Fwd Avg Packets/Bulk                      NaN                      NaN
#  Fwd Avg Bulk Rate                         NaN                      NaN
#  Bwd Avg Bytes/Bulk                        NaN                      NaN
#  Bwd Avg Packets/Bulk                      NaN                      NaN
# Bwd Avg Bulk Rate                          NaN                      NaN
#
#                          Fwd Packet Length Std  Bwd Packet Length Max  ...  \
#  URG Flag Count                       0.328437              -0.297731  ...
#  Min Packet Length                   -0.137333              -0.365553  ...
#  min_seg_size_forward                -0.075503              -0.232879  ...
#  Bwd Packet Length Min               -0.078285              -0.229004  ...
#  Avg Fwd Segment Size                 0.919632              -0.221994  ...
# ...                                        ...                    ...  ...
#  Fwd Avg Packets/Bulk                      NaN                    NaN  ...
#  Fwd Avg Bulk Rate                         NaN                    NaN  ...
#  Bwd Avg Bytes/Bulk                        NaN                    NaN  ...
#  Bwd Avg Packets/Bulk                      NaN                    NaN  ...
# Bwd Avg Bulk Rate                          NaN                    NaN  ...
#
#                          min_seg_size_forward  Active Mean   Active Std  \
#  URG Flag Count                     -0.057450     0.066837    -0.024896
#  Min Packet Length                   0.396536    -0.116335    -0.030198
#  min_seg_size_forward                1.000000    -0.058579    -0.010963
#  Bwd Packet Length Min               0.343618    -0.071126    -0.016336
#  Avg Fwd Segment Size               -0.077440     0.145882    -0.002609
# ...                                       ...          ...          ...
#  Fwd Avg Packets/Bulk                     NaN          NaN          NaN
#  Fwd Avg Bulk Rate                        NaN          NaN          NaN
#  Bwd Avg Bytes/Bulk                       NaN          NaN          NaN
#  Bwd Avg Packets/Bulk                     NaN          NaN          NaN
# Bwd Avg Bulk Rate                         NaN          NaN          NaN
#
#                          Active Max   Active Min  Idle Mean   Idle Std  \
#  URG Flag Count            0.048784     0.071720   0.158294   0.116776
#  Min Packet Length        -0.116084    -0.113898  -0.190135  -0.143862
#  min_seg_size_forward     -0.055414    -0.055221  -0.139772  -0.099363
#  Bwd Packet Length Min    -0.069810    -0.069898  -0.135351  -0.092328
#  Avg Fwd Segment Size      0.127892     0.148842   0.262143   0.223047
# ...                             ...          ...        ...        ...
#  Fwd Avg Packets/Bulk           NaN          NaN        NaN        NaN
#  Fwd Avg Bulk Rate              NaN          NaN        NaN        NaN
#  Bwd Avg Bytes/Bulk             NaN          NaN        NaN        NaN
#  Bwd Avg Packets/Bulk           NaN          NaN        NaN        NaN
# Bwd Avg Bulk Rate               NaN          NaN        NaN        NaN
#
#                          Idle Max   Idle Min     Label
#  URG Flag Count          0.167592   0.121579 -0.463190
#  Min Packet Length      -0.202572  -0.143757 -0.427396
#  min_seg_size_forward   -0.146873  -0.109090 -0.407315
#  Bwd Packet Length Min  -0.140788  -0.107084 -0.365667
#  Avg Fwd Segment Size    0.287524   0.187498 -0.356895
# ...                           ...        ...       ...
#  Fwd Avg Packets/Bulk         NaN        NaN       NaN
#  Fwd Avg Bulk Rate            NaN        NaN       NaN
#  Bwd Avg Bytes/Bulk           NaN        NaN       NaN
#  Bwd Avg Packets/Bulk         NaN        NaN       NaN
# Bwd Avg Bulk Rate             NaN        NaN       NaN
#
# [78 rows x 78 columns]

# %%
sorted_df = df_corr.sort_values(by=' Label',ascending=False)
sorted_df
# Out:
#                           Flow Duration   Total Fwd Packets  \
#  Label                         0.025923           -0.029870
#  Bwd Packet Length Mean        0.176030            0.044903
#  Avg Bwd Segment Size          0.176030            0.044903
# Bwd Packet Length Max          0.176183            0.036765
#  Bwd Packet Length Std         0.164360            0.008661
# ...                                 ...                 ...
#  Fwd Avg Packets/Bulk               NaN                 NaN
#  Fwd Avg Bulk Rate                  NaN                 NaN
#  Bwd Avg Bytes/Bulk                 NaN                 NaN
#  Bwd Avg Packets/Bulk               NaN                 NaN
# Bwd Avg Bulk Rate                   NaN                 NaN
#
#                           Total Backward Packets  Total Length of Fwd Packets  \
#  Label                                 -0.069290                    -0.319693
#  Bwd Packet Length Mean                 0.077473                    -0.199152
#  Avg Bwd Segment Size                   0.077473                    -0.199152
# Bwd Packet Length Max                   0.064136                    -0.184076
#  Bwd Packet Length Std                  0.033976                    -0.184303
# ...                                          ...                          ...
#  Fwd Avg Packets/Bulk                        NaN                          NaN
#  Fwd Avg Bulk Rate                           NaN                          NaN
#  Bwd Avg Bytes/Bulk                          NaN                          NaN
#  Bwd Avg Packets/Bulk                        NaN                          NaN
# Bwd Avg Bulk Rate                            NaN                          NaN
#
#                           Total Length of Bwd Packets   Fwd Packet Length Max  \
#  Label                                       0.041244               -0.321529
#  Bwd Packet Length Mean                      0.162835               -0.209415
#  Avg Bwd Segment Size                        0.162835               -0.209415
# Bwd Packet Length Max                        0.144765               -0.194168
#  Bwd Packet Length Std                       0.116924               -0.189367
# ...                                               ...                     ...
#  Fwd Avg Packets/Bulk                             NaN                     NaN
#  Fwd Avg Bulk Rate                                NaN                     NaN
#  Bwd Avg Bytes/Bulk                               NaN                     NaN
#  Bwd Avg Packets/Bulk                             NaN                     NaN
# Bwd Avg Bulk Rate                                 NaN                     NaN
#
#                           Fwd Packet Length Min   Fwd Packet Length Mean  \
#  Label                                -0.180094                -0.356895
#  Bwd Packet Length Mean               -0.131073                -0.238341
#  Avg Bwd Segment Size                 -0.131073                -0.238341
# Bwd Packet Length Max                 -0.124594                -0.221994
#  Bwd Packet Length Std                -0.120963                -0.214916
# ...                                         ...                      ...
#  Fwd Avg Packets/Bulk                       NaN                      NaN
#  Fwd Avg Bulk Rate                          NaN                      NaN
#  Bwd Avg Bytes/Bulk                         NaN                      NaN
#  Bwd Avg Packets/Bulk                       NaN                      NaN
# Bwd Avg Bulk Rate                           NaN                      NaN
#
#                           Fwd Packet Length Std  Bwd Packet Length Max  ...  \
#  Label                                -0.300271               0.577323  ...
#  Bwd Packet Length Mean               -0.196846               0.961442  ...
#  Avg Bwd Segment Size                 -0.196846               0.961442  ...
# Bwd Packet Length Max                 -0.182455               1.000000  ...
#  Bwd Packet Length Std                -0.176954               0.992683  ...
# ...                                         ...                    ...  ...
#  Fwd Avg Packets/Bulk                       NaN                    NaN  ...
#  Fwd Avg Bulk Rate                          NaN                    NaN  ...
#  Bwd Avg Bytes/Bulk                         NaN                    NaN  ...
#  Bwd Avg Packets/Bulk                       NaN                    NaN  ...
# Bwd Avg Bulk Rate                           NaN                    NaN  ...
#
#                           min_seg_size_forward  Active Mean   Active Std  \
#  Label                               -0.407315     0.022905    -0.070408
#  Bwd Packet Length Mean              -0.238532     0.126631    -0.018005
#  Avg Bwd Segment Size                -0.238532     0.126631    -0.018005
# Bwd Packet Length Max                -0.232879     0.120209    -0.014283
#  Bwd Packet Length Std               -0.234919     0.114848    -0.024741
# ...                                        ...          ...          ...
#  Fwd Avg Packets/Bulk                      NaN          NaN          NaN
#  Fwd Avg Bulk Rate                         NaN          NaN          NaN
#  Bwd Avg Bytes/Bulk                        NaN          NaN          NaN
#  Bwd Avg Packets/Bulk                      NaN          NaN          NaN
# Bwd Avg Bulk Rate                          NaN          NaN          NaN
#
#                           Active Max   Active Min  Idle Mean   Idle Std  \
#  Label                     -0.009271     0.033821   0.087114   0.078023
#  Bwd Packet Length Mean     0.104015     0.131586   0.184541   0.191300
#  Avg Bwd Segment Size       0.104015     0.131586   0.184541   0.191300
# Bwd Packet Length Max       0.100149     0.124584   0.178270   0.181758
#  Bwd Packet Length Std      0.091211     0.120694   0.174000   0.179434
# ...                              ...          ...        ...        ...
#  Fwd Avg Packets/Bulk            NaN          NaN        NaN        NaN
#  Fwd Avg Bulk Rate               NaN          NaN        NaN        NaN
#  Bwd Avg Bytes/Bulk              NaN          NaN        NaN        NaN
#  Bwd Avg Packets/Bulk            NaN          NaN        NaN        NaN
# Bwd Avg Bulk Rate                NaN          NaN        NaN        NaN
#
#                           Idle Max   Idle Min     Label
#  Label                    0.096775   0.061243  1.000000
#  Bwd Packet Length Mean   0.213836   0.116561  0.603299
#  Avg Bwd Segment Size     0.213836   0.116561  0.603299
# Bwd Packet Length Max     0.205558   0.113910  0.577323
#  Bwd Packet Length Std    0.201309   0.110371  0.576155
# ...                            ...        ...       ...
#  Fwd Avg Packets/Bulk          NaN        NaN       NaN
#  Fwd Avg Bulk Rate             NaN        NaN       NaN
#  Bwd Avg Bytes/Bulk            NaN        NaN       NaN
#  Bwd Avg Packets/Bulk          NaN        NaN       NaN
# Bwd Avg Bulk Rate              NaN        NaN       NaN
#
# [78 rows x 78 columns]

# %%
sorted_df[' Label'].values
# Out:
# array([ 1.        ,  0.6032992 ,  0.6032992 ,  0.5773235 ,  0.57615485,
#         0.4542834 ,  0.45347218,  0.44374926,  0.41439887,  0.40808878,
#         0.24773967,  0.12963033,  0.12750281,  0.10545705,  0.10065404,
#         0.09965128,  0.09697462,  0.09677468,  0.08711409,  0.07802336,
#         0.06124316,  0.04124448,  0.04124448,  0.04056489,  0.03382143,
#         0.02592279,  0.02290517,  0.02203038, -0.00203445, -0.00927096,
#        -0.01251879, -0.01251879, -0.02987034, -0.02987034, -0.03554494,
#        -0.03868026, -0.04394218, -0.04394218, -0.05091641, -0.05456023,
#        -0.06174345, -0.06427659, -0.06928971, -0.06928971, -0.07040839,
#        -0.07618285, -0.09038338, -0.12073466, -0.12941767, -0.13992199,
#        -0.18009412, -0.208595  , -0.21218857, -0.21218857, -0.29089561,
#        -0.29205354, -0.30027092, -0.30534405, -0.31867947, -0.31969339,
#        -0.31969339, -0.32152867, -0.3568947 , -0.3568947 , -0.36566745,
#        -0.40731523, -0.42739634, -0.46318953,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan])

# %%
sorted_df[' Label'].values[1:10]
# Out:
# array([0.6032992 , 0.6032992 , 0.5773235 , 0.57615485, 0.4542834 ,
#        0.45347218, 0.44374926, 0.41439887, 0.40808878])

# %% [markdown]
# #### Selected Features are the following

# %%
selected_features = sorted_df.index.values[1:10]
selected_features = np.append(selected_features,' Destination Port')
print(selected_features)
# Out:
# [' Bwd Packet Length Mean' ' Avg Bwd Segment Size' 'Bwd Packet Length Max'
#  ' Bwd Packet Length Std' ' Packet Length Mean' ' Average Packet Size'
#  ' Packet Length Std' ' Max Packet Length' ' Packet Length Variance'
#  ' Destination Port']

# %%
df_high_corr = df[selected_features]

# %%
hist = df_high_corr.hist(figsize=(10,10))

# %% [markdown]
# # 7. [10 pts] Attempt a few classifier models and report their 10-fold CV performance.

# %%
column_names = np.append(selected_features, ' Label')
df = df[column_names]

# %%
df.head()
# Out:
#     Bwd Packet Length Mean   Avg Bwd Segment Size  Bwd Packet Length Max  \
# 0                      0.0                    0.0                      0
# 1                      6.0                    6.0                      6
# 2                      6.0                    6.0                      6
# 3                      6.0                    6.0                      6
# 4                      0.0                    0.0                      0
#
#     Bwd Packet Length Std   Packet Length Mean   Average Packet Size  \
# 0                     0.0                  6.0                   9.0
# 1                     0.0                  6.0                   9.0
# 2                     0.0                  6.0                   9.0
# 3                     0.0                  6.0                   9.0
# 4                     0.0                  6.0                   9.0
#
#     Packet Length Std   Max Packet Length   Packet Length Variance  \
# 0                 0.0                   6                      0.0
# 1                 0.0                   6                      0.0
# 2                 0.0                   6                      0.0
# 3                 0.0                   6                      0.0
# 4                 0.0                   6                      0.0
#
#    Destination Port   Label
# 0       other ports       0
# 1       other ports       0
# 2       other ports       0
# 3       other ports       0
# 4       other ports       0

# %%
df.shape
# Out:
# (225745, 11)

# %%
from sklearn.preprocessing import OneHotEncoder
X = df[selected_features].values
X.shape[1]
# Out:
# 10

# %%
passthrough = []
for i in range(0,X.shape[1]-1):
    passthrough.append(i)

# %%
passthrough
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
from sklearn.compose import ColumnTransformer
c_transf = ColumnTransformer([ 
    ('onehot', OneHotEncoder(), [9]),
    ('nothing', 'passthrough', passthrough)
])
X = c_transf.fit_transform(X).astype(float)

# %%
X.shape
# Out:
# (225745, 16)

# %%
y = df[' Label']

# %%
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0,n_jobs=-1)
kfold = StratifiedKFold(n_splits=10).split(X, y)
scores = []
for k, (train, test) in enumerate(kfold):
     clf.fit(X[train], y[train])
     score = clf.score(X[test], y[test])
     scores.append(score)
     print('Fold: %2d, Acc: %.3f' % (k+1, score))
print("Mean Accuracy", np.mean(scores))
# Out:
# Fold:  1, Acc: 1.000
# Fold:  2, Acc: 1.000
# Fold:  3, Acc: 1.000
# Fold:  4, Acc: 1.000
# Fold:  5, Acc: 1.000
# Fold:  6, Acc: 0.999
# Fold:  7, Acc: 1.000
# Fold:  8, Acc: 1.000
# Fold:  9, Acc: 0.999
# Fold: 10, Acc: 0.998
# Mean Accuracy 0.9993798259270041

# %% [markdown]
# ## Linear SVM

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=0)
kfold = StratifiedKFold(n_splits=10).split(X, y)
scores = []
for k, (train, test) in enumerate(kfold):
     clf.fit(X[train], y[train])
     score = clf.score(X[test], y[test])
     scores.append(score)
     print('Fold: %2d, Acc: %.3f' % (k+1, score))
print("Mean Accuracy", np.mean(scores))
# Out:
# C:\Users\ackch\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Fold:  1, Acc: 0.900
# C:\Users\ackch\anaconda3\lib\site-packages\sklearn\svm\_base.py:977: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Fold:  2, Acc: 0.905
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-c83ad09536cc> in <module>
#       4 scores = []
#       5 for k, (train, test) in enumerate(kfold):
# ----> 6      clf.fit(X[train], y[train])
#       7      score = clf.score(X[test], y[test])
#       8      scores.append(score)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_classes.py in fit(self, X, y, sample_weight)
#     235             self.class_weight, self.penalty, self.dual, self.verbose,
#     236             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 237             self.loss, sample_weight=sample_weight)
#     238
#     239         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     967         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     968         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 969         epsilon, sample_weight)
#     970     # Regarding rnd.randint(..) in the above signature:
#     971     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %% [markdown]
# ## RBF SVM

# %%
from sklearn.svm import SVC
clf = SVC(kernel = 'rbf',random_state=0)
kfold = StratifiedKFold(n_splits=10).split(X, y)
scores = []
for k, (train, test) in enumerate(kfold):
     clf.fit(X[train], y[train])
     score = clf.score(X[test], y[test])
     scores.append(score)
     print('Fold: %2d, Acc: %.3f' % (k+1, score))
print("Mean Accuracy", np.mean(scores))

# %% [markdown]
# # 8. [10 pts] Convert your code to be used for the remaining 7 datasets, i.e. Datasets 2-8.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold

def getInfo(csvPath):
    # Locate and load the data file
    df = pd.read_csv(csvPath)
    # Sanity check
    print('=========================================')
    print('File Path')
    print('-----------------------------------------')
    print(csvPath)
    print('=========================================')
    print('Data Shape');
    print('-----------------------------------------')
    print(f'N rows={len(df)}, M columns={len(df.columns)}')
    print('=========================================')
    print('Feature Names')
    print('-----------------------------------------')
    print(df.columns.values)
    print('=========================================')
    print('LABELS')
    print('-----------------------------------------')
    print(df[' Label'].value_counts())
    print('=========================================')
    print('LABELS AFTER BINARY CONVERSION')
    print('-----------------------------------------')
    df[' Label'] = pd.Series(np.where(df[' Label'] == 'BENIGN', 0, 1), df.index)
    print(df[' Label'].value_counts())
    print('SELECTED FEATURES')
    print('-----------------------------------------')
    df_corr = df.corr()
    sorted_df = df_corr.sort_values(by=' Label',ascending=False)
    selected_features = sorted_df.index.values[1:10]
    print(selected_features)
    df_high_corr = sorted_df[selected_features]
    hist = df_high_corr.hist()
    X = df[selected_features]
    print(X)
    print('X.shape', X.shape)
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    y = df[' Label']
    print('=========================================')
    print('Random Forest Classifier')
    print('-----------------------------------------')
    clf = RandomForestClassifier(random_state=0,n_jobs=-1)
    kfold = StratifiedKFold(n_splits=10).split(X, y)
    scores = []
    for k, (train, test) in enumerate(kfold):
         clf.fit(X[train], y[train])
         score = clf.score(X[test], y[test])
         scores.append(score)
         print('Fold: %2d, Acc: %.3f' % (k+1, score))
    print("Mean Accuracy", np.mean(scores))
    return df

# %% [markdown]
# # 9. [10 pts] Pick a classifier and report it's evaluation for the remaining 7 datasets. Note that one dataset has a single class, which might need an unsupervised learning

# %%
# df = getInfo('Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv');
# Locate and load the data file
df = pd.read_csv('Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv')
# Sanity check
print('=========================================')
print('File Path')
print('-----------------------------------------')
print('=========================================')
print('Data Shape');
print('-----------------------------------------')
print(f'N rows={len(df)}, M columns={len(df.columns)}')
print('=========================================')
print('Feature Names')
print('-----------------------------------------')
print(df.columns.values)
print('=========================================')
print('LABELS')
print('-----------------------------------------')
print(df[' Label'].value_counts())
print('=========================================')
print('LABELS AFTER BINARY CONVERSION')
print('-----------------------------------------')
df[' Label'] = pd.Series(np.where(df[' Label'] == 'BENIGN', 0, 1), df.index)
print(df[' Label'].value_counts())
df.dropna(inplace=True)
indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
df[indices_to_keep].astype(np.float64)
df = df.reset_index()
X = df[selected_features].values
print(X)
print('X.shape', X.shape)
y = df[' Label'].values
print('y.shape', y.shape)
print('=========================================')
print('Random Forest Classifier')
print('-----------------------------------------')
clf = RandomForestClassifier(random_state=0,n_jobs=-1)
kfold = StratifiedKFold(n_splits=10).split(X, y)
scores = []
for k, (train, test) in enumerate(kfold):
     clf.fit(X[train], y[train])
     score = clf.score(X[test], y[test])
     scores.append(score)
     print('Fold: %2d, Acc: %.3f' % (k+1, score))
print("Mean Accuracy", np.mean(scores))
# Out:
# =========================================
# File Path
# -----------------------------------------
# =========================================
# Data Shape
# -----------------------------------------
# N rows=286467, M columns=79
# =========================================
# Feature Names
# -----------------------------------------
# [' Destination Port' ' Flow Duration' ' Total Fwd Packets'
#  ' Total Backward Packets' 'Total Length of Fwd Packets'
#  ' Total Length of Bwd Packets' ' Fwd Packet Length Max'
#  ' Fwd Packet Length Min' ' Fwd Packet Length Mean'
#  ' Fwd Packet Length Std' 'Bwd Packet Length Max' ' Bwd Packet Length Min'
#  ' Bwd Packet Length Mean' ' Bwd Packet Length Std' 'Flow Bytes/s'
#  ' Flow Packets/s' ' Flow IAT Mean' ' Flow IAT Std' ' Flow IAT Max'
#  ' Flow IAT Min' 'Fwd IAT Total' ' Fwd IAT Mean' ' Fwd IAT Std'
#  ' Fwd IAT Max' ' Fwd IAT Min' 'Bwd IAT Total' ' Bwd IAT Mean'
#  ' Bwd IAT Std' ' Bwd IAT Max' ' Bwd IAT Min' 'Fwd PSH Flags'
#  ' Bwd PSH Flags' ' Fwd URG Flags' ' Bwd URG Flags' ' Fwd Header Length'
#  ' Bwd Header Length' 'Fwd Packets/s' ' Bwd Packets/s'
#  ' Min Packet Length' ' Max Packet Length' ' Packet Length Mean'
#  ' Packet Length Std' ' Packet Length Variance' 'FIN Flag Count'
#  ' SYN Flag Count' ' RST Flag Count' ' PSH Flag Count' ' ACK Flag Count'
#  ' URG Flag Count' ' CWE Flag Count' ' ECE Flag Count' ' Down/Up Ratio'
#  ' Average Packet Size' ' Avg Fwd Segment Size' ' Avg Bwd Segment Size'
#  ' Fwd Header Length.1' 'Fwd Avg Bytes/Bulk' ' Fwd Avg Packets/Bulk'
#  ' Fwd Avg Bulk Rate' ' Bwd Avg Bytes/Bulk' ' Bwd Avg Packets/Bulk'
#  'Bwd Avg Bulk Rate' 'Subflow Fwd Packets' ' Subflow Fwd Bytes'
#  ' Subflow Bwd Packets' ' Subflow Bwd Bytes' 'Init_Win_bytes_forward'
#  ' Init_Win_bytes_backward' ' act_data_pkt_fwd' ' min_seg_size_forward'
#  'Active Mean' ' Active Std' ' Active Max' ' Active Min' 'Idle Mean'
#  ' Idle Std' ' Idle Max' ' Idle Min' ' Label']
# =========================================
# LABELS
# -----------------------------------------
# PortScan    158930
# BENIGN      127537
# Name:  Label, dtype: int64
# =========================================
# LABELS AFTER BINARY CONVERSION
# -----------------------------------------
# 1    158930
# 0    127537
# Name:  Label, dtype: int64
# =========================================
# Random Forest Classifier
# -----------------------------------------
# [[1.58045455e+02 1.58045455e+02 9.76000000e+02 ... 2.39686848e+02
#   9.76000000e+02 5.74497850e+04]
#  [1.58045455e+02 1.58045455e+02 9.76000000e+02 ... 2.39686848e+02
#   9.76000000e+02 5.74497850e+04]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [2.09614563e+03 2.09614563e+03 4.34400000e+03 ... 1.24487415e+03
#   4.34400000e+03 1.54971164e+06]
#  [1.77717742e+03 1.77717742e+03 2.89600000e+03 ... 1.05811005e+03
#   2.89600000e+03 1.11959688e+06]
#  [1.75524561e+03 1.75524561e+03 2.89600000e+03 ... 1.06931301e+03
#   2.89600000e+03 1.14343031e+06]]
# X.shape (286452, 9)
# y.shape (286452,)

# %%
np.all(np.isfinite(X))
# Out:
# False

# %%
df[' Destination Port'].isin([20,21,22,23,25,53,80,110,119,123,143,161,194,443])

# %%
df = getInfo('Friday-WorkingHours-Morning.pcap_ISCX.csv');
# Out:
# =========================================
# File Path
# -----------------------------------------
# Friday-WorkingHours-Morning.pcap_ISCX.csv
# =========================================
# Data Shape
# -----------------------------------------
# N rows=191033, M columns=79
# =========================================
# Feature Names
# -----------------------------------------
# [' Destination Port' ' Flow Duration' ' Total Fwd Packets'
#  ' Total Backward Packets' 'Total Length of Fwd Packets'
#  ' Total Length of Bwd Packets' ' Fwd Packet Length Max'
#  ' Fwd Packet Length Min' ' Fwd Packet Length Mean'
#  ' Fwd Packet Length Std' 'Bwd Packet Length Max' ' Bwd Packet Length Min'
#  ' Bwd Packet Length Mean' ' Bwd Packet Length Std' 'Flow Bytes/s'
#  ' Flow Packets/s' ' Flow IAT Mean' ' Flow IAT Std' ' Flow IAT Max'
#  ' Flow IAT Min' 'Fwd IAT Total' ' Fwd IAT Mean' ' Fwd IAT Std'
#  ' Fwd IAT Max' ' Fwd IAT Min' 'Bwd IAT Total' ' Bwd IAT Mean'
#  ' Bwd IAT Std' ' Bwd IAT Max' ' Bwd IAT Min' 'Fwd PSH Flags'
#  ' Bwd PSH Flags' ' Fwd URG Flags' ' Bwd URG Flags' ' Fwd Header Length'
#  ' Bwd Header Length' 'Fwd Packets/s' ' Bwd Packets/s'
#  ' Min Packet Length' ' Max Packet Length' ' Packet Length Mean'
#  ' Packet Length Std' ' Packet Length Variance' 'FIN Flag Count'
#  ' SYN Flag Count' ' RST Flag Count' ' PSH Flag Count' ' ACK Flag Count'
#  ' URG Flag Count' ' CWE Flag Count' ' ECE Flag Count' ' Down/Up Ratio'
#  ' Average Packet Size' ' Avg Fwd Segment Size' ' Avg Bwd Segment Size'
#  ' Fwd Header Length.1' 'Fwd Avg Bytes/Bulk' ' Fwd Avg Packets/Bulk'
#  ' Fwd Avg Bulk Rate' ' Bwd Avg Bytes/Bulk' ' Bwd Avg Packets/Bulk'
#  'Bwd Avg Bulk Rate' 'Subflow Fwd Packets' ' Subflow Fwd Bytes'
#  ' Subflow Bwd Packets' ' Subflow Bwd Bytes' 'Init_Win_bytes_forward'
#  ' Init_Win_bytes_backward' ' act_data_pkt_fwd' ' min_seg_size_forward'
#  'Active Mean' ' Active Std' ' Active Max' ' Active Min' 'Idle Mean'
#  ' Idle Std' ' Idle Max' ' Idle Min' ' Label']
# =========================================
# LABELS
# -----------------------------------------
# BENIGN    189067
# Bot         1966
# Name:  Label, dtype: int64
# =========================================
# LABELS AFTER BINARY CONVERSION
# -----------------------------------------
# 0    189067
# 1      1966
# Name:  Label, dtype: int64
# =========================================
# SELECTED FEATURES
# -----------------------------------------
# [' PSH Flag Count' ' URG Flag Count' ' Destination Port' ' Bwd Packets/s'
#  ' Fwd Packet Length Mean' ' Avg Fwd Segment Size'
#  ' Packet Length Variance' ' Fwd Packet Length Std'
#  ' Fwd Packet Length Max']
# =========================================
# Random Forest Classifier
# -----------------------------------------
#          PSH Flag Count   URG Flag Count   Destination Port   Bwd Packets/s  \
# 0                     0                0               3268        0.141919
# 1                     0                0                389        0.141919
# 2                     0                0                  0        0.000000
# 3                     0                0               5355        0.000000
# 4                     0                0                  0        0.000000
# ...                 ...              ...                ...             ...
# 191028                0                0                 53       32.545727
# 191029                0                0                 53    11695.906430
# 191030                0                0                 53     9009.009009
# 191031                0                0                123       59.375371
# 191032                0                0                 53    13071.895420
#
#          Fwd Packet Length Mean   Avg Fwd Segment Size  \
# 0                         201.5                  201.5
# 1                         201.5                  201.5
# 2                           0.0                    0.0
# 3                          28.0                   28.0
# 4                           0.0                    0.0
# ...                         ...                    ...
# 191028                     45.0                   45.0
# 191029                     40.0                   40.0
# 191030                     45.0                   45.0
# 191031                     48.0                   48.0
# 191032                     34.0                   34.0
#
#          Packet Length Variance   Fwd Packet Length Std  \
# 0                  32016.557820              204.724205
# 1                  30526.000000              204.724205
# 2                      0.000000                0.000000
# 3                      0.000000                0.000000
# 4                      0.000000                0.000000
# ...                         ...                     ...
# 191028              4148.571429                0.000000
# 191029              2764.800000                0.000000
# 191030              5227.200000                0.000000
# 191031                 0.000000                0.000000
# 191032                76.800000                0.000000
#
#          Fwd Packet Length Max
# 0                          403
# 1                          403
# 2                            0
# 3                           28
# 4                            0
# ...                        ...
# 191028                      45
# 191029                      40
# 191030                      45
# 191031                      48
# 191032                      34
#
# [191005 rows x 9 columns]
# X.shape (191005, 9)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-7a7a6773b6d9> in <module>
# ----> 1 df = getInfo('Friday-WorkingHours-Morning.pcap_ISCX.csv');
#
# <ipython-input-44-e93fa249bb03> in getInfo(csvPath)
#      52     scores = []
#      53     for k, (train, test) in enumerate(kfold):
# ---> 54          clf.fit(X[train], y[train])
#      55          score = clf.score(X[test], y[test])
#      56          scores.append(score)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     904             return self._get_values(key)
#     905
# --> 906         return self._get_with(key)
#     907
#     908     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     939             #  (i.e. self.iloc) or label-based (i.e. self.loc)
#     940             if not self.index._should_fallback_to_positional():
# --> 941                 return self.loc[key]
#     942             else:
#     943                 return self.iloc[key]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1035
#    1036         # A collection of keys
# -> 1037         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1038         return self.obj._reindex_with_indexers(
#    1039             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314                 with option_context("display.max_seq_items", 10, "display.width", 80):
#    1315                     raise KeyError(
# -> 1316                         "Passing list-likes to .loc or [] with any missing labels "
#    1317                         "is no longer supported. "
#    1318                         f"The following labels were missing: {not_found}. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Int64Index([ 20901,  23789,  26374,  34541,  36102,\n            ...\n            158875, 164857, 171777, 180400, 189205],\n           dtype='int64', length=27). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
df = getInfo('Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv');

# %%
df = getInfo('Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv');

# %%
df = getInfo('Tuesday-WorkingHours.pcap_ISCX.csv');

# %%
df = getInfo('Wednesday-workingHours.pcap_ISCX.csv');

# %% [markdown]
# ## Unsupervised Dataset

# %%
df = getInfo('Monday-WorkingHours.pcap_ISCX.csv');

# %% [markdown]
# # 10. [10 pts] Briefly write up your thoughts about developing a machine learning model where
# you are not a subject matter expert, such as, developing a cybersecurity intrusion detection
# pipeline as in this assignment.
